# %% [markdown]
# # Run all
#
# Pipeline completa per validare dati, generare grafici, tabelle e riepiloghi testuali.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import load_config, ensure_output_dirs
from src.data_loading import load_all
from src.cli import validate, analyze

config = load_config(PROJECT_ROOT / 'config.yaml')
ensure_output_dirs(config)
data = load_all(config)
print(validate(config, data))
analyze(config, data)
print('Pipeline completata. Output in outputs/.')
# Out:
# OK: users-time.csv valido
# OK: file euristiche valido
# OK: file euristiche valido
# OK: questionario valido
# OK: questionario valido
# Pipeline completata. Output in outputs/.
