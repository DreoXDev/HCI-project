# %% [markdown]
# # Generazione slide
#
# Notebook leggero sopra la CLI. Per l'esecuzione production usare `python -m src.cli generate-slides --auto --overwrite`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.slide_export.pptx_generator import validate_template_structure, validate_slide_assets, generate_slides, format_slide_generation_summary

# %%
template = ROOT / 'slides/templates/Deliveroo_vs_Glovo_clean_python_ready_template.pptx'
config = ROOT / 'slides/config/slide_deck.yml'
validate_template_structure(template)

# %%
missing_assets = validate_slide_assets(config, template_path=template)
missing_assets[:5]

# %%
result = generate_slides(config, template_path=template, overwrite=True)
print(format_slide_generation_summary(result))
