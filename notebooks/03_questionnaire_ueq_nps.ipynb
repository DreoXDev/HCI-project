# %% [markdown]
# # Questionnaire UEQ and NPS

# %%
import sys
from pathlib import Path
import pandas as pd
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from src.config import load_config
from src.data_loading import load_questionnaire
from src.questionnaire import ueq_summary, nps_summary
config = load_config(PROJECT_ROOT / 'config.yaml')
systems = [config['project']['system_1'], config['project']['system_2']]
q1 = load_questionnaire(config['paths']['questionnaire_system_1'])
q2 = load_questionnaire(config['paths']['questionnaire_system_2'])
display(pd.concat([ueq_summary(q1, systems[0]), ueq_summary(q2, systems[1])]))
display(pd.concat([nps_summary(q1, systems[0]), nps_summary(q2, systems[1])]))
