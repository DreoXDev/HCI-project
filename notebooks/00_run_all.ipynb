# %% [markdown]
# # Run all
#
# Wrapper leggero sopra la CLI. Per produzione usare `python -m src.cli full-pipeline --plot-style both --generate-slides --no-export-pdf`.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import load_config
from src.cli import full_pipeline

config = load_config(PROJECT_ROOT / 'config.yaml')
full_pipeline(config)
print('Pipeline completa rigenerata. Output in outputs/.')
